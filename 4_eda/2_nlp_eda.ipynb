# %%
import pandas as pd

# %%
btc_news = pd.read_parquet('../2_data_processing/text_data/btc_news_processed.parquet.gzip')
eth_news = pd.read_parquet('../2_data_processing/text_data/eth_news_processed.parquet.gzip')
btc_tweets = pd.read_parquet('../2_data_processing/text_data/btc_tweets_processed.parquet.gzip').set_index('tweet_id')
eth_tweets = pd.read_parquet('../2_data_processing/text_data/eth_tweets_processed.parquet.gzip').set_index('tweet_id')
reddit_r_bitcoin = pd.read_parquet('../2_data_processing/text_data/reddit_r_bitcoin_processed.parquet.gzip')
reddit_r_ethereum = pd.read_parquet('../2_data_processing/text_data/reddit_r_ethereum_processed.parquet.gzip')

# %%
print(f' Number of news:\t\t   {len(btc_news) + len(eth_news):,}')
print(f' Number of reddit posts:\t  {len(reddit_r_bitcoin) + len(reddit_r_ethereum):,}')
print(f' Number of tweets:\t\t{len(btc_tweets) + len(eth_tweets):,}')
# Out:
#  Number of news:		   53,469
#  Number of reddit posts:	  337,886
#  Number of tweets:		1,837,953

# %%
btc_news_vader = pd.read_parquet('../3_nlp_models/0_vader/btc_news_vader.parquet.gzip')
btc_tweets_vader = pd.read_parquet('../3_nlp_models/0_vader/btc_tweets_vader.parquet.gzip').set_index('tweet_id')
btc_reddit_vader = pd.read_parquet('../3_nlp_models/0_vader/reddit_r_bitcoin_vader.parquet.gzip')
btc_news_roberta = pd.read_parquet('../3_nlp_models/1_twitter_roberta_pretrained/btc_news_roberta_pretrained.parquet.gzip')
btc_tweets_roberta = pd.read_parquet('../3_nlp_models/1_twitter_roberta_pretrained/btc_tweets_roberta_pretrained.parquet.gzip').set_index('tweet_id')
btc_reddit_roberta = pd.read_parquet('../3_nlp_models/1_twitter_roberta_pretrained/reddit_r_bitcoin_roberta_pretrained.parquet.gzip')
btc_news_bart = pd.read_parquet('../3_nlp_models/2_bart_zero_shot/btc_news_bart_mnli.parquet.gzip')
btc_tweets_bart = pd.read_parquet('../3_nlp_models/2_bart_zero_shot/btc_tweets_bart_mnli.parquet.gzip').set_index('tweet_id')
btc_reddit_bart = pd.read_parquet('../3_nlp_models/2_bart_zero_shot/reddit_r_bitcoin_bart_mnli.parquet.gzip')
btc_news_roberta_finetuned = pd.read_parquet('../3_nlp_models/3_roberta_finetuned/second_results/btc_news_roberta_finetuned.parquet.gzip')
btc_tweets_roberta_finetuned = pd.read_parquet('../3_nlp_models/3_roberta_finetuned/second_results/btc_tweets_roberta_finetuned.parquet.gzip')
btc_reddit_roberta_finetuned = pd.read_parquet('../3_nlp_models/3_roberta_finetuned/second_results/reddit_r_bitcoin_roberta_finetuned.parquet.gzip')

eth_news_vader = pd.read_parquet('../3_nlp_models/0_vader/eth_news_vader.parquet.gzip')
eth_tweets_vader = pd.read_parquet('../3_nlp_models/0_vader/eth_tweets_vader.parquet.gzip').set_index('tweet_id')
eth_reddit_vader = pd.read_parquet('../3_nlp_models/0_vader/reddit_r_ethereum_vader.parquet.gzip')
eth_news_roberta = pd.read_parquet('../3_nlp_models/1_twitter_roberta_pretrained/eth_news_roberta_pretrained.parquet.gzip')
eth_tweets_roberta = pd.read_parquet('../3_nlp_models/1_twitter_roberta_pretrained/eth_tweets_roberta_pretrained.parquet.gzip').set_index('tweet_id')
eth_reddit_roberta = pd.read_parquet('../3_nlp_models/1_twitter_roberta_pretrained/reddit_r_ethereum_roberta_pretrained.parquet.gzip')
eth_news_bart = pd.read_parquet('../3_nlp_models/2_bart_zero_shot/eth_news_bart_mnli.parquet.gzip')
eth_tweets_bart = pd.read_parquet('../3_nlp_models/2_bart_zero_shot/eth_tweets_bart_mnli.parquet.gzip').set_index('tweet_id')
eth_reddit_bart = pd.read_parquet('../3_nlp_models/2_bart_zero_shot/reddit_r_ethereum_bart_mnli.parquet.gzip')
eth_news_roberta_finetuned = pd.read_parquet('../3_nlp_models/3_roberta_finetuned/second_results/eth_news_roberta_finetuned.parquet.gzip')
eth_tweets_roberta_finetuned = pd.read_parquet('../3_nlp_models/3_roberta_finetuned/second_results/eth_tweets_roberta_finetuned.parquet.gzip')
eth_reddit_roberta_finetuned = pd.read_parquet('../3_nlp_models/3_roberta_finetuned/second_results/reddit_r_ethereum_roberta_finetuned.parquet.gzip')

# %%
btc_news_merged = pd.concat([btc_news,
                             btc_news_vader.vader_score,
                             btc_news_bart.bart_mnli_bullish_score,
                             btc_news_roberta.twitter_roberta_pretrained_score], axis=1)
btc_tweets_merged = pd.concat([btc_tweets,
                               btc_tweets_vader.vader_score,
                               btc_tweets_bart.bart_mnli_bullish_score,
                               btc_tweets_roberta.twitter_roberta_pretrained_score], axis=1)
btc_reddit_merged = pd.concat([reddit_r_bitcoin,
                               btc_reddit_vader.vader_score,
                               btc_reddit_bart.bart_mnli_bullish_score,
                               btc_reddit_roberta.twitter_roberta_pretrained_score], axis=1)

eth_news_merged = pd.concat([eth_news,
                             eth_news_vader.vader_score,
                             eth_news_bart.bart_mnli_bullish_score,
                             eth_news_roberta.twitter_roberta_pretrained_score], axis=1)
eth_tweets_merged = pd.concat([eth_tweets,
                               eth_tweets_vader.vader_score,
                               eth_tweets_bart.bart_mnli_bullish_score,
                               eth_tweets_roberta.twitter_roberta_pretrained_score], axis=1)
eth_reddit_merged = pd.concat([reddit_r_ethereum,
                               eth_reddit_vader.vader_score,
                               eth_reddit_bart.bart_mnli_bullish_score,
                               eth_reddit_roberta.twitter_roberta_pretrained_score], axis=1)

# %%
print(f'''Top Bitcoin posts by dataset and by LLM model:

---------------------      
Bitcoin News
---------------------      

Top VADER news:

{btc_news_merged.sort_values('vader_score', ascending=False).title.head(10).values}

Top Twitter RoBERTa news:

{btc_news_merged.sort_values('twitter_roberta_pretrained_score', ascending=False).title.head(10).values}

Top BART MNLI news:

{btc_news_merged.sort_values('bart_mnli_bullish_score', ascending=False).title.head(10).values}

Top RoBERTa finetuned news:

{btc_news_roberta_finetuned.sort_values('roberta_finetuned_score', ascending=False).text.head(10).values}

---------------------      
Bitcoin Tweets
---------------------      

Top VADER tweets:

{btc_tweets_merged.sort_values('vader_score', ascending=False).content_cleaned.head(10).values}

Top Twitter RoBERTa tweets:

{btc_tweets_merged.sort_values('twitter_roberta_pretrained_score', ascending=False).content_cleaned.head(10).values}

Top BART MNLI tweets:

{btc_tweets_merged.sort_values('bart_mnli_bullish_score', ascending=False).content_cleaned.head(10).values}

Top RoBERTa finetuned tweets:

{btc_tweets_roberta_finetuned.sort_values('roberta_finetuned_score', ascending=False).text.head(10).values}

---------------------      
Bitcoin Reddit
---------------------      

Top VADER reddit posts:

{btc_reddit_merged.sort_values('vader_score', ascending=False).content.head(10).values}

Top Twitter RoBERTa reddit posts:

{btc_reddit_merged.sort_values('twitter_roberta_pretrained_score', ascending=False).content.head(10).values}

Top BART MNLI reddit posts:

{btc_reddit_merged.sort_values('bart_mnli_bullish_score', ascending=False).content.head(10).values}

Top RoBERTa finetuned reddit posts:

{btc_reddit_roberta_finetuned.sort_values('roberta_finetuned_score', ascending=False).text.head(10).values}
''')
# Out:
# Top Bitcoin posts by dataset and by LLM model:
#
# ---------------------
# Bitcoin News
# ---------------------
#
# Top VADER news:
#
# ['Smarter Smart Contracts With Artificial Intelligence - CoinDesk'
#  'Love Bitcoin? Mine Your Values - CoinDesk'
#  'The Truth About Artificial Intelligence and Creativity - CoinDesk'
#  'Reinvent Money to Reward Virtue - CoinDesk'
#  'United Traders - Strong Buy! - Cointelegraph'
#  'Dubai Airport Free Zone welcomes crypto assets with new SCA agreement - Cointelegraph'
#  'Taiwan Approves 24 Crypto Platforms, Including WOO Network, for AML Compliance - CoinDesk'
#  'Sure Mining, Worth Investing! - Cointelegraph'
#  'Magic Eden Will Reward Loyal Traders With Discounts, Free NFTs - Decrypt'
#  'The Importance of Supporting a Robust Developer Ecosystem - Cointelegraph']
#
# Top Twitter RoBERTa news:
#
# ['‘This Is So Awesome!’: Al Roker and Wife Deborah Roberts Inspire Fans with Heartfelt Announcement - Yahoo News'
#  'Happy 10th Birthday, Bitcoin.org! - Modern Consensus'
#  "Powers On... It's been a wonderful life (week): SEC Commissioner ... - Cointelegraph"
#  'FanAnywhere is pleased and immensely proud to announce itself as a portfolio company of Polygon Studio - Cointelegraph'
#  '2022 ABGA Blockchain Gaming Summit was a big success on Sept. 27 - Cointelegraph'
#  'An amazing race during the bear market: Seedify launches Amazy with impressive results - Cointelegraph'
#  "Happy International Women's Day! Leaders share their experiences in crypto - Cointelegraph"
#  'Phemex brings joy to your home this Christmas - Cointelegraph'
#  'Happy 5th Birthday Ethereum: this is your life - Decrypt'
#  'Harvard named world’s best university for the 9th year in a row - Yahoo Finance']
#
# Top BART MNLI news:
#
# ['A Bullish Case for Bitcoin | Video - CoinDesk'
#  'The Puell Multiple Is Turning Bullish on Bitcoin - CoinDesk'
#  'Bitcoin On-Chain Metrics Look Bullish, Bitfinex Report Highlights - CoinDesk'
#  "Bitcoin's 'Guppy' Indicator Flashes Green for Bulls - CoinDesk"
#  "Failed Signature Bank Developments; Bitcoin's Bullish Sentiment - CoinDesk"
#  'Bullish on Bitcoin, US Senator Ted Cruz wants Texas to be a crypto oasis - Cointelegraph'
#  "Three Key Reasons Why Bitcoin's Macro Chart Is Still Bullish - Bitcoinist"
#  'Bitcoin (BTC) Comeback to $8000 Signals a Crypto Bull Run - BlockPublisher'
#  'Silvergate, SBV collapse ‘definitely good’ for Bitcoin, Trezor exec says - Cointelegraph'
#  "Bitcoin's 'Super Guppy' Price Indicator Flips Bullish in First Since 2018 - CoinDesk"]
#
# Top RoBERTa finetuned news:
#
# ['3 reasons why Bitcoin price has not been able to rally back above $40K - Cointelegraph'
#  'FairySwap, the first DEX on the Findora blockchain, launches on mainnet - Cointelegraph'
#  "Biden's Executive Order on Crypto Is 'Balanced' In Mitigating Risk ... - CoinDesk"
#  'DeFi Is Getting Even Weirder - CoinDesk'
#  'Pension Fund-Backed Parataxis Capital Shakes Off Crypto Winter With New Fund - CoinDesk'
#  'Domain name “Bitcoin.com” briefly goes on sale for $100 million - CryptoSlate'
#  'Someone Borrowed $1.3M in Ethereum Using Mutant Ape NFTs as Collateral - Decrypt'
#  'Metaverse tokens surge after Meta tanks, Dorsey roasts Diem after it ... - Cointelegraph'
#  'Self-Hosted Bitcoin Wallets Become Front Line in Fight Over Crypto ... - CoinDesk'
#  'Unpacking the Latest Bitcoin ETF Rejections - CoinDesk']
#
# ---------------------
# Bitcoin Tweets
# ---------------------
#
# Top VADER tweets:
#
# ['#Bitcoin Chart Looking pretty good, pretty, pretty, pretty, pretty, good. pretty, pretty good.'
#  '#Bitcoin: Wealth. Justice. Peace.' 'Clean 👌 #Bitcoin'
#  'Yes, #Bitcoin. Good. Good.' 'Hahaha YES!!!! #BTC'
#  '#Bitcoin looking good 👌👌' '#Bitcoin rewards freedom.'
#  'Gift Freedom #Bitcoin' 'True love #bitcoin' 'True love. #bitcoin']
#
# Top Twitter RoBERTa tweets:
#
# ["We are so excited for @TheBitcoinConf in a few weeks! 🧡Can't wait to see everyone🧡 #Bitcoin"
#  'We are so excited and happy for @TimaTakesOff! Baby in #Bitcoin coming Jan 2023.'
#  "Hi guys!! Say hello to my new beautiful Ape @MegapontNFT !! So charming and rich, huh?!🙉🥰 I'm so excited about the $Mega token!! Let's go!!!! 🚀🚀😍#NFT #NFTs #ETH #Bitcoin #Stacks"
#  'Wooooo! Super excited about the hard fork !!!!! :D :D :D #HardForkParty #Ethereum #HardFork #Bitcoin #Blockchain'
#  '👏👏👏👏🥳 LETS GOOOOO!!! What a great way to wake up on a Monday morning!!!!! We are getting noticed more and more!! Oh there’s so much to be excited about with #GroveToken!! #BSC #ETH #BitMart #Crypto #CryptoNews #Bullish #cryptocurrency #btc'
#  'Another beautiful #Crypto morning! Can’t wait to see 16k #btc and $700 #ETH 💎🤲🏻 #cryptocurrencies'
#  'Happy birthday to my #Bitcoin bestie of 17 years (😱) @paulapendleyLAW!! Can’t wait to celebrate you! 😘'
#  'Good morning guys!🌞🌞 We are very excited to see the passionate communication of our friends in the seer community every day!🥰🥰 The most important thing is that we have seer partners all over the world, come and join us!🤩🤩🤩 #Web3 #BTC #blockchain #seer #cryptocurrency'
#  'Good morning from the whole squad!! 🤩🤩 #BTC #HappyFriday #Squad'
#  'Thanks for the pizza @HuobiGlobal!! Happy #Bitcoin Pizza Day! I hope you are all celebrating 🥳']
#
# Top BART MNLI tweets:
#
# ['#bitcoin the Bull scenario 🐂 🚀'
#  '#bitcoin: -Bullish Case for Bitcoin @real_vijay -Shelling Out @NickSzabo4 -Planting Bitcoin @danheld -Gradually then Suddenly @parkeralewis -Little Bitcoin Book @jimmysong -Bitcoin Standard @saifedean -PlanB S2F @100trillionUSD -SLP 71 @stephanlivera -Mises/Rothbard @NakamotoInst'
#  'Bullish case for Bitcoin 📈 • Weekly close above $9650 later this week • Rally towards ~$10300 • Pullback into $9650 a week or two later • Successful retest of $9650 as Weekly support • Followed by another challenge of $10100 - $10400 $BTC #Crypto #Bitcoin'
#  '$BTC #bitcoin Bullish scenario:'
#  '#BTC weekly the most bullish chart for risk assets -RSI back-test breakout ✅ -MACD 🐂 cross w/⬆️histogram momentum✅ -#SPY reclaimed 200w ma ✅ -Bond capitulation ✅ -Majority calling for 10K BTC ✅'
#  '$BTC Bullish scenario #Bitcoin'
#  'OUTCOME IS BULLISH FOR BITCOIN “the Board voted unanimously to maintain the interest rate paid on reserve balances at 0.15 percent, effective Janu- ary 27, 2022.” #FOMC #MINUTES #DXY #BTC'
#  '#Bitcoin * USDT The current bullish scenario is this'
#  "Detailed look on this bullish 1-2 flat pattern count on #Bitcoin. C wave looks incomplete, but I don't like what the 4 does to the remainder of the count. My first thought is that this may be invalidated and we are going to new lows, but lets see how it develops. 1/"
#  '#Bitcoin Indicator Turns Bullish for First Time in 8 Months $BTC']
#
# Top RoBERTa finetuned tweets:
#
# ['VALUE TRANSFER: In June 2020, stablecoins seem to have come into their own as a tool for value transfer, surpassing #bitcoin in total transfer value for the first time. Read more in the full Rise of Stablecoins report from @CoinMetrics and Bitstamp:'
#  '120,000,000 sat (1.2 #bitcoin) bounty offered by @jack for best #nostr-based GitHub replacement 👀'
#  "Bad: Trusting a cryptocurrency exchange based solely on their auditors' say so Better: Insisting on being able to check your exchange's proof of reserves yourself Best: Learning to be your own bank and self-custodying your #Bitcoin"
#  '- 48m millionaires in the world. - Only 21m Bitcoins will ever exist. They won’t even be able to buy half a #Bitcoin each! 😂 That’s why we buy #BTC now not later 😉'
#  '🚨ATTN: all #Crypto/ #GameFi projects! Let Us Launch You! 🚀 The #Axion Launchpad is accepting launch applications! Apply below: #Bitcoin #NFT #BTC #cryptocurrency #NFTs #ETH #DeFi #FTM #NFTCommunity #Ethereum #BSC #BNB #Polygon #AVAX #TR9'
#  'I hope you bought the dip!! ⚡️ #Bitcoin'
#  'Bitcoin IS Another Store of Wealth: BlackRock CEO - #BTC \u2066@MatiGreenspan\u2069'
#  '#FTT Short reached TP1 50% profit💥💥💥 Closed half ✅✅✅ Still hold half TP2 at Do Kwon🚂💵💵💵💵💵 Join us and WIN in ALL MARKETS! 100% VERIFIED! Click⤵️ #FTT #FTX #Binance #cz_binance #Bitcoin #Crash'
#  'The PlusToken cryptocurrency scam, thought to involve the theft of over 200,000 #BTC, has involved a significant sell-off as the scammers try to cover their tracks. $BTC'
#  "Going LIVE in the Ravenist Discord right now to draw the winners of today's Open Edition Art & #Crypto Giveaways! 🎨 🤖 #RVN #BTC #NFT #Giveaway"]
#
# ---------------------
# Bitcoin Reddit
# ---------------------
#
# Top VADER reddit posts:
#
# ['Good | Good' 'Wow. | Just wow.' 'Better asset | &#x200B;'
#  'The best project | Super' 'Help | please help need food'
#  'Grateful heart | grateful to be here'
#  'please help | please help Confirm the sending.'
#  "who's suddenly rich? | wow"
#  'Perfect execution... | Perfect execution...'
#  'Best secure mobile wallets? | Opinions please!']
#
# Top Twitter RoBERTa reddit posts:
#
# ['So excited I finally own 50 btc!! | Thank you Bitcoin community!'
#  "Walmart now sells Bitcoin mining hardware!! | Quite excited by this news!!! - Isn't that cool?? :) Check out this link:"
#  '100,000 new members on r/Bitcoin in one day! | Welcome! :) This is so exciting!'
#  '2014 was a great year for this amazing technology. Happy New Year to everyone in this sub. | Bitcoin became a huge part of my life in 2014. Cheers!'
#  "Thanks for giving me a new series to watch, r/bitcoin | Mr. Robot is an awesome series and I can't wait to see what happens in the next episode."
#  "Excited to buy some pizza tomorrow with bitcoin. | Two Dogs Taproom in Tokyo has such awesome pizza. Can't wait to buy some. Anyone else excited for pizza and/or bitcoin?"
#  "Fiverr accepts Bitcoin! | This made me happy and excited! We're gonna make it."
#  "WALMART IS BACK AT eGIFTER! | It's baaaack! We are excited to announce that the card you have been waiting for is here ([again] just in time for Father's Day: [**WALMART!**] [Have fun storming the castle!]"
#  'Happy New Year!! | Happy new year!!! Bitcoin breaks 10k on Chinese New Year Day. I can tell it’s going to be a good year'
#  "Just sold my first artwork with Bitcoin!! | I'm super excited as yesterday I sold a few prints of my art with bitcoin! The transaction was extremely fast and easy! I'm just loving it! My art"]
#
# Top BART MNLI reddit posts:
#
# ["Foreign Exchange scandal will promote Bitcoin use! Getting screwed again by banks... | German watchdog plans to step up FX probe at Deutsche. Britain's Financial Conduct Authority began a formal investigation into possible manipulation in the $5.3 trillion-a-day global foreign exchange market. Source:"
#  'Venezuela with 99% likely default, Greece crashing HARD and EU/US Stock market taking a beating. Bullish indicators for bitcoin! :-) | Venezuela: Greece: US/EU Stock Market:'
#  'Good news for Bitcoin | Visa: New European proposals will disrupt online shopping'
#  'the stock market tanking is a positive for bitcoin. | People need a reason to exit stocks. The general markets have been incredibly strong up for a long time (multiple years) and only recently have they begun to crash. Millions of investors (and institutions) have had zero incentive to invest in a new asset class when their portfolios were doing extremely well. Anyone else have thoughts on this?'
#  'This is the most bullish for Bitcoin! | Here we have again the compilation of the most bullish news in the space. Check it out! **TLDR: The Bitcoin Conference attracts 12,000 attendees, El Salvador makes Bitcoin a legal tender, Blockstream and Square partner up to construct a solar-powered Bitcoin Mining facility.** \\- Bitcoin Conference over 12,000 attendees \\- Bitcoin legal tender in El Salvador \\- Paypal over 300 million volume in bitcoin \\- HRF funded bitcoin companies with $210K. \\- Blockstream and Square to build solar powered Bitcoin Mining facility - and more! Adoption keeps increasing! Enjoy!!!'
#  "A killer application for bitcoin: a bidding fee auction | A bidding fee auction (also called a penny auction) open source, so it can't possible to be a scam (reviewed the source code). Similar to MADBID but with true actors, and with more information like the true sum of money putted on an article by all partecipants. What do you think about? Why not adding a condition that the item can be sell after that the sum of pennies is equal to real value of it, and a quote of extramoney earned is put automatically into a multisignature address and reused for example as a lottery between all partecipant (always with an open source code)"
#  "I think killer app for Bitcoin would be some accounting application for running errands, which would lets me send someone I know to the grocery store for Bitcoin instead of going myself. | If you're using Bitcoin and your grocery store don't accept Bitcoins yet, this type of app could both help get involved in BTC people that surrounds you. Imagine if there would be an app which could act like accounting software: e.g. you need to send someone to buy milk, that person could login to web-site to receive funds for that order & can accomplish that order by getting extra fee for running errands. Those person will go to purchase that stuff for you for fiat, and you don't need to spend your time to go to the grocery store, and also you're keeping yourself from temptation of ordering wrong stuff, because from now on you will be following strict purchase list accomplished by someone else."
#  "It is bullish that bitcoin didn't drop despite Yuan rise against the Dollar... | It used to be a very strong correlation between bitcoin prices and the Yuan/Dollar exchange rate. Now the Yuan is rising against the Dollar and it's not only not droping, but climbing steadily. Perhaps as a result of the new Chinese regulations? The fact is that volatility is decreasing and there are more buys coming from the west, as evidenced by new trading volumes and ratios and the fact that the price remains a bit lower in China. Source for Yuan raising against the Dollar:"
#  'BitPay Adds Museum to Client Base | Great news for the Bitcoin Bowl'
#  "Libra + eUSD = Bitcoin Bull | Here's why Libra will ultimately be the catalyst that brings a new ATH (and was likely behind today's price jump) No idea why the mods keep removing this post but /bitcoinmarkets seems happy to allow uncensored discussion on a perfectly rule abiding post."]
#
# Top RoBERTa finetuned reddit posts:
#
# ['Ineligible to use the Coinbase platform | I tried buying some coins just to hold on to, and I got an automated email saying my transaction was cancelled for security reasons. So I contacted support and they said: "Unfortunately a manual review has determined that you are ineligible to use the Coinbase platform to purchase Bitcoin. We’re sorry for any inconvenience that this may cause." Has this happened to anyone else?'
#  "Bitcoin is currently under attack by short sellers, here's what YOU can do to help. | Bitcoin's nascent market has made it a speculators dream. This having some positives such as increased liquidity for legitimate users, also has its negatives. Those betting against bitcoin, now have enormous profit incentive to do so. Let's make sure it doesn't happen. Short sellers can only borrow a limited amount of BTC before being faced with a short squeeze. 1). Allocate a certain portion of your paycheck towards bitcoin. This strategy practiced over the last 5 years has made people wealthier then they could ever imagine. Bitcoin's current market cap of 7.5bil is still small, there is no reason 75bil cannot be hit. Every $1 spent on bitcoin today may potentially be worth $10 tomorrow. Short sellers will face a dwindling supply of coins to borrow. 2) Do not spend your bitcoin's with Coinbase or Bitpay merchants. Why? Because these merchant's are merely in it for the fiat sales. Coinbase and Bitpay are glorified 1 way exchange services which convert BTC into Fiat, thereby depressing FIAT bid books. This is harmful to liquidity. Stick to business's which SETTLE in bitcoin, after all we are trying to build a financial system that is independent of the legacy monopoly. Coinbase and Bitpay are traditional state sanctioned corporations interested in making a PROFIT for shareholders as well as the government itself. This itself is an anti-thesis to P2P money. 3) Have a sitdown with friends who care. Most people are so hopelessly enamored with the present system mainly due to the state run education system, they will attack any perceived threat against it without even knowing it. These people are not ready for crypto, it is a waste of time to engage them. 4) Stay away from legacy institutions. We aren't here to revolt against the powers that be, we don't have to. With bitcoin we can simply IGNORE THEM. Our silence is the most powerful statement against the accusers and deceivers. In the end, did you really think the state along with the banking cartels would willfully give up their control of money?"
#  "What's bitcoin for?? | Sorry I'm scared of asking questions I don't already know the answer for! What's this 'money' for, anyway?"
#  'US Plan to Delist Chinese Stocks Could Trigger Massive Bitcoin Buying Spree | The mounting tensions between the US and China as a result of the ongoing pandemic have contributed to global instability and could ultimately provide a major boost to Bitcoin. The United States House of Representatives is now spearheading an effort to delist Chinese stocks from the US markets, claiming that they have long been able to benefit from US listings without the companies having to abide by the same rules as domestic companies. If the government is successful in their move to delist these companies, it could provide a major boost to Bitcoin as more Chinese citizens turn to crypto to escape the mounting economic turbulence. Ironically, this effort is being driven by Representative Brad Sherman – an outspoken critic of Bitcoin and other digital assets. Tensions Between US and China Mount as Government Moves to Delist Chinese Stocks The ongoing global pandemic has largely been blamed on China by officials within the US government, who now appear to be taking actions to increase the country’s accountability. In a recent interview with MarketWatch, Representative Sherman noted that “it’s time for China to blink first” while speaking about his newly introduced “Holding Foreign Companies Accountable Act.” Rep. Sherman, who has long been an adversary of Bitcoin and crypto in general, explained that this newly introduced act isn’t being floated with the goal of desilting Chinese companies from the US markets, but rather to force them to adhere to the US capital-market standards. “THE PURPOSE HERE IS NOT TO DELIST OR DE-REGISTER; IT’S TO DEMAND THAT CHINA DO WHAT EVERY OTHER COUNTRY HAS DONE AND AGREE THAT IF THEIR COMPANIES WANT TO PARTICIPATE IN U.S. CAPITAL MARKETS, THEY AGREE TO LIVE BY U.S. CAPITAL-MARKETS RULES…TIME FOR CHINA TO BLINK FIRST FOR THE BENEFIT OF INVESTORS,” HE STATED. If this act is passed, it could create even greater tension between the two countries, potentially having grave impacts on the recently passed trade deal. Rep. Sherman believes that the bill will be successfully passed before the end of summer. Here’s How This Could Give Bitcoin a Boost Because the delisting of Chinese companies from the US markets could have dire impacts on the country’s economy, citizens residing there may continue turning to alternative investments like Bitcoin to hedge their portfolios. This growth has been fueled by investors in China and other countries moving to add USD exposure to their portfolios. The imminent inflation that the US dollar will soon see, however, may also lead some of these investors to convert their USDT into Bitcoin in order to avoid the impacts of the United States’ immense money printing, thus giving BTC a major boost.'
#  'Bad time to invest in bitcoin with the price so high? or... | Or is it really going to skyrocket like people are predicting? People predicted BTC going up over $100k in the summer of 2019 when it it $12k... What do you think'
#  'we need open hardware, NOW. | no, not just we bitcoiners, but everybody. can someone actually explain to me what purpose linux or any other open source software project serves, when it is being run on proprietary closed source hardware with friggin backdoors? wtf!'
#  'Where is the best place to watch the Bcash circus? | Coinbase doesn’t update fast enough.'
#  "Newbie buying guide | Hey guys Long time lurker here. There was a post on here about a guideline for newbies about buying bitcoin, but i lost it somehow. I know tons of people probably come here for advice and i hope i can also. I've been slowly just buying Bitcoin on coinbase for the past few weeks, every paycheque. I dont think i have the nerve to trade. I think i would rather invest and hold. I assume thats what everyone will tell me lol. Any other strong advice for a newbie? Wish i could find that post. thanks guys/gals"
#  "Can someone please explain to me why Facebook is banning Bitcoin, et al news/ads? | I find it strange because the announcement comes just a few weeks after Zuck expressed an interest in crypto currencies. So why ban access to info about crypto on the FB platform? Do you think it's FUD? Do you think FB has alterior motives (e.g., starting their own crypto currency or exchange)? I'm just curious to know what you all think. Any thoughts are welcome."
#  'Should Bitcoin be a "regulator-compliant payment system" or "censorship-resistant means of value transfer"? (The answer is "Yes!") | The thought here is simply this: **Instead of the Bitcoin community trying to decide between the two competing drivers of regulatory compliance and censorship resistance, why not take advantage of Bitcoin\'s "nigh-fungability" to pursue both endeavours and allow a market to organically form to enable the movement of bitcoins between the two camps?** Imagine a (very possible) future where major regulators from around the world decide to institute a white listing policy for bitcoin addresses. For transactions to be considered compliant, they would need to start and remain within this network of white listed addresses (or otherwise be white listed). The addresses will be linked to real world identities held on private (at least until hacked) databases under the control of organisations appointed by the regulators. What will this mean? Well, Bitcoin will be split in two. Terrible, yes? Well maybe not. The white listed bitcoins will now be able to comply with all current AML and KYC regulations (including the dreaded [FATF Recommendation 16] The strongest reasons put forward to stop Bitcoin would be moot, at least in the case of white listed bitcoins. The prospects for widespread acceptance would increase dramatically. But we now need to trust a third party? Well, no. The "free" bitcoins will still exist. They will still be trust minimised and work could continue to improve their anonymity further. As both free and white listed bitcoins will exist, markets will inevitably form to allow exchange between the two sides of the same bitcoin. Furthermore, as these coins are on the same blockchain, mechanisms will form to move directly between them. For example, claims of "loss" or "theft" could allow a user to trustlessly convert white listed bitcoins to free bitcoins and government amnesties could provide a free to white listed transfer mechanism. The free bitcoins will gain from the increased resources brought to bitcoin because of its regulated white listed brethren. The white listed bitcoins will gain from the advances in anonymity contributed by the free bitcoin community. White listing is nearly inevitable and it will most likely be enforced by powerful government agencies and implemented external to the Bitcoin protocol. As such, we as a community will be limited in how much we can resist its implementation. However, I hope that the above thought experiment shows that even if white listing were to occur, Bitcoin would be just fine.']

# %%
print(f'''Top Ethereum posts by dataset and by LLM model:

---------------------      
Ethereum News
---------------------      

Top VADER news:

{eth_news_merged.sort_values('vader_score', ascending=False).title.head(10).values}

Top Twitter RoBERTa news:

{eth_news_merged.sort_values('twitter_roberta_pretrained_score', ascending=False).title.head(10).values}

Top BART MNLI news:

{eth_news_merged.sort_values('bart_mnli_bullish_score', ascending=False).title.head(10).values}

Top RoBERTa finetuned news:

{eth_news_roberta_finetuned.sort_values('roberta_finetuned_score', ascending=False).text.head(10).values}

---------------------      
Ethereum Tweets
---------------------      

Top VADER tweets:

{eth_tweets_merged.sort_values('vader_score', ascending=False).content_cleaned.head(10).values}

Top Twitter RoBERTa tweets:

{eth_tweets_merged.sort_values('twitter_roberta_pretrained_score', ascending=False).content_cleaned.head(10).values}

Top BART MNLI tweets:

{eth_tweets_merged.sort_values('bart_mnli_bullish_score', ascending=False).content_cleaned.head(10).values}

Top RoBERTa finetuned tweets:

{eth_tweets_roberta_finetuned.sort_values('roberta_finetuned_score', ascending=False).text.head(10).values}

---------------------      
Ethereum Reddit
---------------------      

Top VADER reddit posts:

{eth_reddit_merged.sort_values('vader_score', ascending=False).content.head(10).values}

Top Twitter RoBERTa reddit posts:

{eth_reddit_merged.sort_values('twitter_roberta_pretrained_score', ascending=False).content.head(10).values}

Top BART MNLI reddit posts:

{eth_reddit_merged.sort_values('bart_mnli_bullish_score', ascending=False).content.head(10).values}

Top RoBERTa finetuned reddit posts:

{eth_reddit_roberta_finetuned.sort_values('roberta_finetuned_score', ascending=False).text.head(10).values}
''')
# Out:
# Top Ethereum posts by dataset and by LLM model:
#
# ---------------------
# Ethereum News
# ---------------------
#
# Top VADER news:
#
# ['WOO Network CEO on Winning Milestone AML Approval From Taiwan - CoinDesk'
#  'Smarter Smart Contracts With Artificial Intelligence - CoinDesk'
#  'Love Bitcoin? Mine Your Values - CoinDesk'
#  'The Truth About Artificial Intelligence and Creativity - CoinDesk'
#  'Reinvent Money to Reward Virtue - CoinDesk'
#  'United Traders - Strong Buy! - Cointelegraph'
#  'Dubai Airport Free Zone welcomes crypto assets with new SCA agreement - Cointelegraph'
#  'Taiwan Approves 24 Crypto Platforms, Including WOO Network, for AML Compliance - CoinDesk'
#  'How smart contracts can improve efficiency in healthcare - Cointelegraph'
#  'Bahamian Supreme Court Approves Liquidators for FTX Assets - CoinDesk']
#
# Top Twitter RoBERTa news:
#
# ['Happy 10th Birthday, Bitcoin.org! - Modern Consensus'
#  'Great news for strategic traders — Earn easily with CoinEx’s spot grid feature! - Cointelegraph'
#  "Powers On... It's been a wonderful life (week): SEC Commissioner ... - Cointelegraph"
#  'FanAnywhere is pleased and immensely proud to announce itself as a portfolio company of Polygon Studio - Cointelegraph'
#  'Happy Birthday, Bitcoin! Industry players share a few words - Cointelegraph'
#  'An amazing race during the bear market: Seedify launches Amazy with impressive results - Cointelegraph'
#  'Blockchain Fest Singapore 2023 Wraps Up with Great Success - Cointelegraph'
#  "Happy International Women's Day! Leaders share their experiences in crypto - Cointelegraph"
#  'Phemex brings joy to your home this Christmas - Cointelegraph'
#  'Happy 5th Birthday Ethereum: this is your life - Decrypt']
#
# Top BART MNLI news:
#
# ["Ethereum price 'bullish triangle' puts 4-year highs vs. Bitcoin within reach - Cointelegraph"
#  'Ethereum’s Road to $2K: 3 Reasons to Be Bullish - Yahoo Finance'
#  "Ethereum to $2K? ETH price 'bull flag' hints at September gains versus Bitcoin, dollar - Cointelegraph"
#  'Ethereum Price Flashing Bullish — Can ETH Trigger an Altcoin Revival? - Cointelegraph'
#  'Ethereum to $10K? Classic bullish reversal pattern hints at potential ETH price rally - Cointelegraph'
#  'Coinbase new blockchain seen as ‘massive confidence vote’ for Ethereum - Cointelegraph'
#  'Analysis of Ethereum\'s "Whales" Led Investor to Bullish Conclusions - Blockonomi'
#  'Investors bullish on Ethereum ahead of much-hyped CME futures ... - CryptoSlate'
#  "Bitcoin Is Soaring, Boosting Ethereum, Ripple's XRP And Litecoin--Here's Why - Forbes"
#  'Here is why strong post-Merge fundamentals could benefit Ethereum price - Cointelegraph']
#
# Top RoBERTa finetuned news:
#
# ['Bitmain IPO: Trial by Fire for the Mining Equipment Giant - Cointelegraph'
#  'Clearview AI Lawyer Tor Ekeland Says Your Face Is Public Property - CoinDesk'
#  'Binance.US Accused of Misleading Investors in Class-Action Lawsuit Over Terra - CoinDesk'
#  'Bitcoin Price Passes $3,700 to Hit One-Month High - CoinDesk'
#  'Privacy Is a Human Right – and the 118th Congress Must Defend It - CoinDesk'
#  'Australian Lending Startup Loda Gets $15M to Further Crypto Collateralization Efforts - CoinDesk'
#  'How to stake and earn AAVE: Lending rates compared - finder.com.au'
#  'No, PayPal Did Not Resurrect Its ‘Misinformation’ Penalty - Decrypt'
#  'Investor: 4chan has become crypto’s “largest market driver” after Chainlink boom - CryptoSlate'
#  'Cybercriminals Go Phishing For Jaxx Wallet Users - BleepingComputer']
#
# ---------------------
# Ethereum Tweets
# ---------------------
#
# Top VADER tweets:
#
# ['Love love love #Ethereum' 'Nice! #progress #ethereum' 'good luck #ETH'
#  'WOOHOO! #ethereum' 'Lol. Funny if true. #ethereum'
#  'Congratulations Letesenbet!! Congratulations #Eth'
#  '@HeftyHeroes Free #ETH wow!!!!!!' 'Amazing! #ethereum'
#  'Congratulations #Eth' '#eth lmao']
#
# Top Twitter RoBERTa tweets:
#
# ["🌞 Happy fri-YAY frens! Just a reminder that you're awesome 🤍 We can't wait to laugh and decompress with everyone this evening on our Friday space 🎤 #womeninweb3 #NFTCommunity #ETH"
#  '🤩 So hyped for what the #Ethereum community will bring to the world in 2020💪 🥳 Happy New Year everyone 🥳 🦄#ethldn'
#  "Good morning to every beautiful storkholder! $KTO @KounotoriToken Are you all excited for the big news??????? I myself am so excited and can't wait tbh 🚀🚀🚀🚀 #LBOW #staking #eth"
#  "We're very happy to reveal that #Zippie has a brand new look! We love it and we hope you do, too. #ethereum $ZIPT #blockchain"
#  'Happy birthday to my @Pocket_Cows family! I’m so proud to be part of the fam! I can’t wait to continue to grow with you all! And all of the new family members to come ❤️ happy birthday to US! @Dougy_buller #NFT #pocketcows #eth'
#  "Hi guys!! Say hello to my new beautiful Ape @MegapontNFT !! So charming and rich, huh?!🙉🥰 I'm so excited about the $Mega token!! Let's go!!!! 🚀🚀😍#NFT #NFTs #ETH #Bitcoin #Stacks"
#  'Today is a very epic day since 2/4 of the ✨Diosas✨ @ProfessorSt0sh1 + @StonedLayla celebrate their birthdays 🎂 🥳🍾 Have a wonderful day ❤️ We love and appreciate everything y’all ladies do! We will celebrate soon 🥳 #nfts #WomeninNFTs #nft #eth 🔗'
#  'Wooooo! Super excited about the hard fork !!!!! :D :D :D #HardForkParty #Ethereum #HardFork #Bitcoin #Blockchain'
#  '👏👏👏👏🥳 LETS GOOOOO!!! What a great way to wake up on a Monday morning!!!!! We are getting noticed more and more!! Oh there’s so much to be excited about with #GroveToken!! #BSC #ETH #BitMart #Crypto #CryptoNews #Bullish #cryptocurrency #btc'
#  'Fantastic news!!! #streamr data market place will be ready by Q2! It’s very soon! So excited! More news in May, maybe 😍? #cryptocurrencies #ethereum #IoT #$DATA #blockchain']
#
# Top BART MNLI tweets:
#
# ['My latest Martian, the ETH is strong with this one. @SaveMartiansNFT #Ethereum #NFT #nfts #NFTcollection'
#  '#Ethereum bullish descending wedge breakout #Altseason2021 #cryptocurrencies #cryptocurrency #Crypto #Bitcoin #Litecoin #Ethereum #LINK #BTC #LTC #ETH'
#  'ETHEREUM IS BULLISH | MERGE CONFIRMED | RUSSIA DIGITAL RUBLE | CRYPTO NEWS 🚨 In Todays Video: - Ethereum Merge Confirmed - Digital Ruble 2024 - #Ethereum and #Bitcoin Analysis 💰 WATCH THIS VIDEO 💰 ⬇️ LINK BELOW ⬇️'
#  '#Ethereum Weekly looking bullish here with a cup and handle pattern Top Goon X also giving us fibonacci criteria for a move. Breakout target: $5,000+ Notes in chart:'
#  "#Ether's current price action is #bullish and indicating more gains toward $700.00 in the near term. #Analysis #Ethereum"
#  '#Ethereum is bullish within bull flag formation. Can move up and down between 74000 and 79500 before making another leg up to May high at 82400. Next important level is May 2018 lower high at 85900 and February 2018 month open at 123800. #ETH $ETH #Crypto #cryptocurrecy'
#  'A positive indicator for #ethereum! With its expertise, $ETH has proven the possibility of creating new areas of #blockchain application, and we hope that in the future the trend towards creating new approaches and mechanics will continue ✅ Good luck @VitalikButerin!'
#  "$ETH $BTC pair bull flag forming for #Ethereum against #Bitcoin but i'd like to see a drop till the red zone for the ultimate buy before the flippenin so yea, i'm confused what the next move will be, so playing this level by level for now"
#  'The bull case for #Ethereum in a nutshell and how it relates to #Bitcoin. It is a little long, but even if you strongly disagree with the points made here it will help you understand the perspective of $ETH investors.'
#  '#ETH at 1150 #Bullish on trend (Ascending Triangle). Probable target at 1250 with dip local LOWS (20MA) for support retest #Ethereum #Layer1 #Metaverse #NFT #Web3 #DCA #HODL #Buythedip']
#
# Top RoBERTa finetuned tweets:
#
# ['This one gonna melt faces #CraftyMetaverseV2 Available on both #BSC & #ETH Staking platform #NFTs #P2E game Virtual art studio #ERC CA: 0x34e02BCF32C578fEad586a5C6Ab18a1d46aA9214 #BSC CA : 0x7C23751C8CCc19D0A0a9a7f1fF52e213161118Cd'
#  '#NFTGiveaway 🎉 Prize 🏆5x WL Rules: ⭐️Follow @guessthedip & @NIFTYConnect ⭐️❤+RT ⭐️Tag 3 ⏰48Hr #NFTCommunity #lunatic #Ethereum #NFTs #nftart #ETH #ETHNFTs #ETHGiveaway'
#  'Grateful to have such a vibrant and 🌏 international community. 🙏🙏 $CHA #ICO #TRON #BNBChain #Ethereum'
#  "😆 This is a safe space to admit 😈 sometimes it's hard to ignore the Lil' Villain inside of us🙃 #lilvillainsmint #nfts #ethereum #eth #nft #crypto #openseanft #nftart #cryptocurrency #nftartists #nftartist #cryptoartist #artwork #nftcollector #opensea #artoftheday #cryptoart"
#  'There is a HUGE miss understanding on $MATIC / @0xPolygon price: Price haven’t done a pump and now will consolidate. Price is correcting the huge underpriced value vs benefits and will catch-up with the real price pretty soon. 8-10usd / 20ksats #ETH ❤️ @0xPolygon'
#  'Only 2 days left to help us expand #Ethereum knowledge to all corners of the world: @ethereumecf @ethdotorg @ethereum'
#  'We may be in a #crypto #nft #nfts #bearmarket but find affordable #NFTProjects like @toymories and let them earn you $$$$ harvest #meth @BullsApesProj sweep these while they are affordable #eth @apocalypticapes @AAPEQueens @ZinuToken @LazyLionsNFT @DegenToonz'
#  'Swachh Referral Program: We are all set to launch to over referral program on our #discord. Top 10 referrals earns $SCX worth $1000. Join now to participant in in the hunt. #Referral #Airdrop #Ethereum #ICO #BTC'
#  'Which #Crypto conferences would you like to see Quai attend in 2023?🌍 Let us know in the comments below!👇 #QuaiNetwork #Quai #Consensus #BTCMiami #SXSW #Permissionless #ETHCC5 #ETHParis #DevCon #WBSDubai #token2049 #BTC #ETH #SOL #Aptos #Sui #AVAX #KBW2023 #WebSummit #mainnet'
#  'In @TheSandboxGame anyone can create unique worlds and fun game experiences available for all to play through LAND! #Blockchain #blockchaintechnology #crypto #ethereum #NFT #gaming #GamingNews #FridayReads #FridayMotivation']
#
# ---------------------
# Ethereum Reddit
# ---------------------
#
# Top VADER reddit posts:
#
# ['Please post healthy peers here: | Thanks.' 'lmao | &#x200B;'
#  'ENS is ON! | Good luck everyone :)'
#  'VERY ANNOUNCE | Wow! Many happy. Such announce. Much integration! Such friends Dogecoin Reddit! Very thanks. Excite!'
#  'MOO HA HA | Hello World.'
#  '[recommendations please] currently best Ethereum Android wallet? | thx'
#  "Tomshwom's Advanced Crypto Security Guide | Tomshwom's Advanced Crypto Security Guide Privacy, Security, and Trust Wallet Analysis Creating a Secure Wallet"
#  'Trust wallet (IOS) | Is trust wallet for iphone safe?'
#  'Please answer honestly | [View Poll]' 'Endless fork. | lmao.']
#
# Top Twitter RoBERTa reddit posts:
#
# ['☀️ just bought my first ETH, super excited 🌟 | The title says it all:)'
#  'Happy birthday Ethereum from the EEA! | Happy 5th birthday Ethereum from the Enterprise Ethereum Alliance! And hopefully you managed to catch our inaugural EEA annual seminar today too. Great content:'
#  'Happy 7000 subscribers! :) | Getting just more and more fun by the day!'
#  'The best gift for humanity this year was... | **...the launch of Ethereum!** Thank you Vitalik, Gavin, Jeffrey and the whole EthDev team and Ethereum foundation! Happy holidays to the Ethereum community!'
#  'VERY ANNOUNCE | Wow! Many happy. Such announce. Much integration! Such friends Dogecoin Reddit! Very thanks. Excite!'
#  'wish you a very happy birthday to Ethereum | Wish You A Very Happy Birthday To Ethereum, you cute girl. You make us happy with your smart contracts and innovation.'
#  'Happy new year to all 🥳🥳 | Ethereum Blockchain community is one of the most powerful and active community of all the time. Let’s strive together for the better finance of tomorrow 👏🏻'
#  'Happy 6000 subscribers! | Woohoo. More amazing people delving into what could be possible with Ethereum!'
#  "Happy New Year to everyone | Just want to wish a Happy New Year to the Ethereum community. 2016 is going to be a great year with a lot of success and happiness. By the way, don't forget how amazing all of you are ;)"
#  'Goal :D | I just want to share with you guys that I achieved my goal today. Such a beautiful day!!! First node. Acquired.']
#
# Top BART MNLI reddit posts:
#
# ["Shanghai is bullish for Ethereum | One of the most significant events for the Ethereum blockchain is likely to be the Shanghai upgrade. Currently planned for the second half of 2023, the Shanghai upgrade will implement a number of improvements to Ethereum. Chief among them is the ability for ETH stakes to withdraw both their staked coins and accrued rewards. Users have helped to validate transactions on the so-called Beacon Chain since December 2020, when the proof-of-stake network launched. But so far staking has been a one-way trip: Funds were locked in the deposit contract while Ethereum developers built out the network in real-time. I'm so into tracking everything happening in DeFi, I also started looking more into chain analysis, but there are plenty of tools, these days I'm using Toshi Tools and it seems great. However, I'm sure that this upcoming upgrade has the ability to increase the popularity of ETH staking. It will drive competition between staking protocols to users’ benefit, while also improving the security of Ethereum’s new PoS chain. What do you expect from it?"
#  "You can now mint on Polygon and sell on the Ethereum mainnet | Very bullish stuff, the Shoyu project is letting artists mint on Polygon and sell on the Ethereum mainnet. I think this is going to go a long way in supporting small artists who might not be able to mint on Ethereum directly while still helping Ethereum grow. Maybe this will put Polygon haters to rest, They're not trying to kill Ethereum. They want it to thrive and this is added to prove of that IMO. What are your thoughts? I don't completely understand how all this works but it seems bullish to me."
#  'Low Hanging Fruit for Ethereum - Uber and Lyft are both being sued by their drivers. | Uber ($40B company) and Lyft are now being sued by their own drivers who say: "drivers should be reclassified as employees as opposed to independent contractors." Ethereum could easily eat both of these companies\' lunches - a nice little "smart contract appetizer" if you will :)'
#  "Can you please share resources for fundamental anylses for Ethereum? | Ethereum is great, leadership is awesome, it is the new internet, eth2 bullish yay! Most of the stuff out there is around this. Can you please share resources for better understanding for people who are not cypto traders? I'd like to know what makes ETH better for the future, what are risks etc. Thank you"
#  'Bullish on Ethereum! DeFi 2020 | Decentralized Finance is the biggest topic in FinTech and over 350 companies are striving to bring it to reality on Etheruem’s platform. Around $854 million in ETH is locked up in smart contracts while staking ETH has been targeted for potential 10.4% returns if ETH 2.0 launches with 2 million ETH in stake. Bitspark cash points are growing in liquidity daily and making it easier for cash buyers to purchase ERC20 stable coins and tokens. Bullish on Ethereum! [defi guide]'
#  'OmiseGO meets with APEC about future of Ethereum | The CEO of OmiseGO met with [APEC] today to talk about the power of Ethereum to advance payments and financial services. APEC is the Asia Pacific Economic Committee and they coordinate free trade between over 20 countries including China, US, Canada, Australia and all major SE Asian countries. Very promising stuff for Ethereum and OmiseGO!'
#  'CryptoKitties is good for Ethereum | I have been in ETH a long time and other than the DAO (and yes we all know how that ended) have never been more excited about the future of ETH since after seeing CryptoKitties. Before if someone where to ask me how ETH is useful I could site concepts like DApps and smart contracts and ICOs etc but what I was describing to them never really felt REAL. As stupid as it sounds CryptoKitties feels REAL. The game elegantly demonstrates both the value of digital scarcity as well as the vast potential of smart contracts in a way that is simple and intuitive. After trying it out for just a few minutes I was suddenly able to imagine dozens of new possibilities for the potential uses of ETH. You could raise virtual race horses and have them race against each other with randomized weighted outcomes and people could make bets and watch the races. You could keep actual Pokemon created by Nintendo and have them battle each other on a world wide arena. You could setup virtual shops in digital worlds like Second Life and sell the products and services directly for ETH. And this was just off the top of my head in like the first 5 minutes. Cryptogaming has the potential to emerge as a whole new genre of gaming where the stakes and outcomes of each game can be linked to something real. As always, I understand there are definitely infinite ways to screw this all up but nonetheless it is exciting to see it in its inception.'
#  "SportX, a new sports betting exchange built on Ethereum; bets can be made with DAI on 17 sports markets | This is great for Ethereum and Maker/DAI, and for the punters out there, they have an article explaining why they'll beat the competition: - Bet with Dai Stablecoin – On other sports betting dapps, betting with a volatile cryptocurrency makes it hard to estimate profits. On SportX, all bets are placed in Dai, a stablecoin pegged to the US Dollar. 1 Dai = 1 USD, always. - Set Your Own Odds – SportX is a peer-to-peer sports betting app, where users set their own odds and bet against other users. SportX bettors have total freedom to set their own odds using Bookmaker mode. - [...]"
#  "This could be the best thing that happened to Ethereum | The current mindset seems to be that Ethereum is doomed if it does (fork) or doomed if it doesn't. I don't buy that. If Ethereum navigates safely through this crisis it will emerge much stronger. It would demonstrate decentralisation guided by effective thought leadership (for want of a better description). I may be too optimistic but Ethereum seems better placed to affect change than other cryptocurrencies ..."
#  'There are some major universities using Ethereum based DAOs to help teach Web3 development for students | And I mean MAJOR. I’m talking universities like MIT, Harvard, Oxford and many more working with Ethereum based organizations like Bitdao to help students become Web3 builders. Well technically they’re working with Edudao but its all funded by Bitdao apparently which just so happens to be built on Ethereum. This is major news for Ethereum considering how much exposure this could end up giving for crypto and blockchain. Yeah these universities aren’t really accessible to the most of us, but if this works out then I don’t see why other more mainstream universities wouldn’t start implementing something similar. Imagine how much of a push this would give for mainstream adoption. These students are the up and coming working class and leaders of the world in a couple of decades. With them being exposed to blockchain at such a young age, the possibility of them implementing that tech into our everyday life, and taking advantage of its perks, would increase drastically. This way Ethereum would technically be considered one of the pioneers since it’s enabled the building of projects that are funding these activities in a decentralized non-hierarchical manner, something that many universities could benefit from if you ask me.']
#
# Top RoBERTa finetuned reddit posts:
#
# ["Pantera Hiring for Marketing &amp; IR | Pantera Capital, a Menlo Park-based blockchain and cryptocurrency focused investment firm, is looking for a Marketing & Investor Relations Associate. Primary responsibilities include managing the firms marketing program through investor letters, website, fund presentations, social media and speaking engagements. Secondary responsibilities include investor relations tasks, such as, client database updating, gathering investor documentation, existing and potential investor correspondence and event planning. Responsibilities: * Manage the production of the firm’s Investor Letters. Work closely with the investment team to create interesting and topical content for our monthly letters. * Maintain the firm’s website by adding and updating content and registering new users in our client database. * Manage the firm’s social media presence through Twitter, LinkedIn and other social media marketing avenues. * Create, update and maintain the firm’s investor presentations for the fund offerings managed by the firm. * Research potential speaking engagement and help prepare speaking presentations. * Update client database in Saleforce. * Correspond with existing and/or potential investors. * Gather information on investor in funds managed by the firm. Qualifications: * Strong academic background * Exceptional verbal/written communication and interpersonal skills * Knowledgeable and passionate about blockchain/cryptocurrency technologies * Extensive knowledge of hedge fund strategies and analytical methodologies is advantageous * Must be a self-starter who has proven ability to cultivate relationships and help improve overall client relationship process/structure * Attention to detail and concern for quantitative accuracy * Excellent personnel and project management skills If you're interested email us your resume at IR@panteracapital.com"
#  "Anybody else bothered by the severe intellectual decline in this subreddit since the hardfork? | There are hardly any technical discussions anymore. r/ethtrader is constantly leaking and its over-invested users are relentlessly spamming this subreddit with attacks against ETC. This is worse than the Bitcoin blocksize drama, people are getting really aggressive, there are organized smear campaigns, public cheering for attacking each other, and so on. Can we please just move forward? If you don't like ETC, sell it and move on. Done. If you don't like ETH sell it and move on. Done."
#  "Peer to peer betting? | I'm a bit new to ethereum, and I'm trying to learn about it by thinking through possible use cases. It seems like a simple use case for ethereum would be a peer to peer betting program. One possible version could work something like this: 1. Receive equal amount of bitcoin from two parties. 2. Query the API that is meant to settle the bet. If the API is down, the bet is off, so return the bitcoins to each party. 3. Award the bitcoins to the winner of the bet. Is this a possible ethereum program? (One question would be--how would the ethereum program control BTC balances while keeping the private key hidden?) Why or why not? Does something like this already exist?"
#  "0.8.1 Mist Browser Stops Getting Blocks | I'm running 0.8.1 Mist on Linux and when started it syncs up with the blockchain and connects to peers, but then stops receiving blocks. I've let it go for as long as two hours without getting a block. If I quit it and then reopen it syncs up again and then does not receive any additional blocks. Any one else experiencing the same issue? I know a new release is coming up soon, but wanted to see if this was a known issue or just something I'm dealing with."
#  "Idle Finance interest rates? | Interested in your experience with Idle Finance. I'm wary of the Idle Finance USDC interest rate (currently 20.35%). How can the USDC interest rate be that high if it is rebalancing between Compound (8.86%) and Fulcrum (1.29%)?"
#  'If DAO holders lose all, it means 200 million USD less to invest into the Ethereum ecosystem. | We need a fork that will return the coins. I think the DAO should fail and lose all of its money but this is just to much money which would go into this ecosystem by investments by the DAO. If no fork: then 15% will be put on the market for sale which will be horrible, and also 200 million USD less will be invested into Ethereum projects, which horrible as well. The DAO needed a cap when they raised funds. Lesson learned. Return tokens with a fork and dissolve the DAO and start again.'
#  'Setting up Testnet and starting with dapps on Mac | I have seen a couple of older threads with some good information, but was wondering if someone could help me find a good resource to get started on setting up the Ethereum testnet and start playing with solidity and ultimately building some beginner dapps'
#  'Ages investing in cryptocurrencies. (Poll Results) | Pie Chart of results 11 (1 Vote or 0.5%) Most likely a fake "other" but I left it. 14-17 (5 Votes or 2.6% 18-25 (75 Votes or 39.7%) 26-35 (69 Votes or 36.5%) 36-45 (22 Votes or 11.6%) 46-55 (14 Votes or 7.4%) 55+ (3 Votes or 1.6%) Hey guys, here are the results of the POLL after almost 20 hours. I found it interested that 18-25 years old is the most populated age group investing in cryptocurrencies and hopefully that means a long bright future for the technology. I figured I\'d answer some questions and pass them along to you guys for farther discussion in the comments. What age group I\'m in? 18-25 Age when I began investing? 17, I have known about cryptocurrencies since I was 14-15 years old. I never understood them but knew about them. When I turned 17 I started getting paid in BTC when I sold old shoes/games/etc. Currently I invest in BTC and other alt coins and plan to HODL till the future. How I found out about Cryptocurrencies? I believe I first heard about specifically bitcoin 5 years ago. Someone I played console games with was talking about how it is used in the dark web to transfer money with out the government knowing. Should have invested then haha Theres my story. Hope to hear from more people!'
#  "Johoe's mempool analyser is now available for Ethereum | Have you ever wanted to use [Jochen Hoenicke] great tool for mempool analysis for Ethereum? Well now you can! It is available here: This is a port of Johoe's great tool that lets you visualise pending transactions. The tool shows a count of the pending transaction, the total amount of ETH available for mining, and the amount of gas in the txpool. I helped developing the tool. Hope you find it helpful. Cheers :)"
#  "Today is my first day as member of thr ethereum community | Any advise you can give a noobie? /s Seriously though, I just bought in. It's my first time owning ethereum. Buy when there is blood on the streets brothers!"]
